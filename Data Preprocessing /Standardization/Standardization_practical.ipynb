# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 71    24            27000          0
# 393   60            42000          1
# 3     27            57000          0
# 314   39            79000          0
# 285   37            93000          1

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1),
                                                    df['Purchased'],test_size=0.3,
                                                    random_state = 10)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_test.sample(5)
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 295   36            63000
# 66    24            19000
# 357   41            72000
# 138   28            59000

# %% [markdown]
# ### Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)  # fit the scaler to train set, so that it can learn the parameters

# transform train and test data using standard scaler
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.10639192, -0.98126643],
#        [ 0.91259164, -1.44163648],
#        [ 1.20329206, -0.98126643],
#        [-0.25021   ,  0.19843182],
#        [-0.63781054, -0.34825761],
#        [ 0.42809096, -0.17561884],
#        [ 0.5249911 ,  1.69463449],
#        [ 0.71879137, -1.38409022],
#        [-0.83161082, -0.77985453],
#        [ 1.97849315,  0.71634813],
#        [ 0.33119082, -0.54966951],
#        [-0.25021   ,  0.77389439],
#        [-0.83161082,  0.14088557],
#        [ 0.23429069, -0.37703074],
#        [ 0.33119082, -1.1539052 ],
#        [ 1.88159301,  0.11211244],
#        [ 0.71879137, -1.09635894],
#        [-0.44401027, -1.21145146],
#        [-0.25021   ,  2.21255079],
#        [-0.25021   , -0.26193823],
#        [ 0.13739055,  0.08333931],
#        [ 1.10639192,  0.54370936],
#        [ 1.00949178, -1.1539052 ],
#        [ 1.30019219,  2.18377766],
#        [-1.02541109,  0.74512126],
#        [ 1.5908926 ,  0.97530628],
#        [-0.25021   , -1.24022458],
# ...

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns = X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    1.106392        -0.981266
# 1    0.912592        -1.441636
# 2    1.203292        -0.981266
# 3   -0.250210         0.198432
# 4   -0.637811        -0.348258
# ..        ...              ...
# 275  1.590893        -1.268998
# 276  1.397092         1.953593
# 277 -0.831611         0.284751
# 278  0.137391        -0.261938
# 279  0.428091         1.090399
#
# [280 rows x 2 columns]

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.428091        -0.146846
# 1   -0.056410         0.025793
# 2    0.428091         0.572482
# 3    0.912592        -0.664762
# 4   -1.413012        -0.635989
# ..        ...              ...
# 115  0.718791        -1.268998
# 116 -0.056410        -0.492123
# 117  2.172293         0.917760
# 118 -0.540910         1.349357
# 119  0.428091         0.284751
#
# [120 rows x 2 columns]

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.582143     70103.571429
# std     10.338381     34816.878679
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     88250.000000
# max     60.000000    150000.000000

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.6          70103.6
# std     10.3          34816.9
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70000.0
# 75%     46.0          88250.0
# max     60.0         150000.0

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.582143     70103.571429
# std     10.338381     34816.878679
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     88250.000000
# max     60.000000    150000.000000

# %% [markdown]
# ## Why Scaling is Important?

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train, y_train)
lr_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
## Checking the accuracy
from sklearn.metrics import accuracy_score
print("Actual: ",accuracy_score(y_test, y_pred))
print("Scaled: ",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual:  0.6916666666666667
# Scaled:  0.875

# %%
y_test.shape
# Out:
# (120,)

# %%
y_pred.shape
# Out:
# (120,)

# %%
## Now we'll using the Decision Tree Classifier to check there would be any effect of Scaling the values as we know
## there would be no use of it , so let's check it

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
dt_scaled.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)

# %%
## Checking the accuracy score
print("Actual: ",accuracy_score(y_pred,y_test))
print("Scale: ",accuracy_score(y_pred_scaled,y_test))
# Out:
# Actual:  0.875
# Scale:  0.875
